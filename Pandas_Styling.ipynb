# %% [markdown]
# <a href="https://colab.research.google.com/github/bimbeo/Web/blob/master/Pandas_Styling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để làm nổi bật các số âm màu đỏ và số dương màu đen.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight the negative numbers red and positive numbers black.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-1-output.png)

# %%
import pandas as pd
import numpy as np
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
print("Original array:")
print(df)
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color
print("\nNegative numbers red and positive numbers black:")
df.style.applymap(color_negative_red)
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212 -0.770033 -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720
#
# Negative numbers red and positive numbers black:
# <style  type="text/css" >
#     #T_95ceaa7a_a6f7_11ea_a700_0242ac1c0002row0_col0 {
#             color:  black;
#         }    #T_95ceaa7a_a6f7_11ea_a700_0242ac1c0002row0_col1 {
#             color:  black;
#         }    #T_95ceaa7a_a6f7_11ea_a700_0242ac1c0002row0_col2 {
#             color:  red;
#         }    #T_95ceaa7a_a6f7_11ea_a700_0242ac1c0002row0_col3 {
# ...

# %% [markdown]
# **2, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Chuyển đổi một số giá trị thành giá trị nan. Viết chương trình Pandas sẽ làm nổi bật các giá trị nan.**
#
# **Create a dataframe of ten rows, four columns with random values. Convert some values to nan values. Write a Pandas program which will highlight the nan values.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-2-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
def color_negative_red(val):
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color
print("\nNegative numbers red and positive numbers black:")
df.style.highlight_null(null_color='red')
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Negative numbers red and positive numbers black:
# <style  type="text/css" >
#     #T_d54d548a_a6f7_11ea_a700_0242ac1c0002row0_col2 {
#             background-color:  red;
#         }    #T_d54d548a_a6f7_11ea_a700_0242ac1c0002row3_col3 {
#             background-color:  red;
#         }    #T_d54d548a_a6f7_11ea_a700_0242ac1c0002row4_col1 {
#             background-color:  red;
# ...

# %% [markdown]
# **3, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để làm nổi bật giá trị tối đa trong mỗi cột.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight the maximum value in each column.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-3-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
def highlight_max(s):
    '''
    highlight the maximum in a Series green.
    '''
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

print("\nHighlight the maximum value in each column:")
df.style.apply(highlight_max,subset=pd.IndexSlice[:, ['B', 'C', 'D', 'E']])
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Highlight the maximum value in each column:
# <style  type="text/css" >
#     #T_0496eaf8_a6f8_11ea_a700_0242ac1c0002row2_col4 {
#             background-color:  green;
#         }    #T_0496eaf8_a6f8_11ea_a700_0242ac1c0002row6_col2 {
#             background-color:  green;
#         }    #T_0496eaf8_a6f8_11ea_a700_0242ac1c0002row8_col1 {
#             background-color:  green;
# ...

# %% [markdown]
# **4, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để làm nổi bật giá trị tối thiểu trong mỗi cột.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight the minimum value in each column.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-4-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
def highlight_min(s):
    '''
    highlight the minimum in a Series red.
    '''
    is_max = s == s.min()
    return ['background-color: red' if v else '' for v in is_max]

print("\nHighlight the minimum value in each column:")
df.style.apply(highlight_min,subset=pd.IndexSlice[:, ['B', 'C', 'D', 'E']])
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Highlight the minimum value in each column:
# <style  type="text/css" >
#     #T_1d7ec284_a6f8_11ea_a700_0242ac1c0002row1_col2 {
#             background-color:  red;
#         }    #T_1d7ec284_a6f8_11ea_a700_0242ac1c0002row2_col1 {
#             background-color:  red;
#         }    #T_1d7ec284_a6f8_11ea_a700_0242ac1c0002row8_col4 {
#             background-color:  red;
# ...

# %% [markdown]
# **5, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để làm nổi bật giá trị tối đa trong hai cột cuối cùng.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight the maximum value in last two columns.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-5-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
def highlight_max(s):
    '''
    highlight the maximum in a Series green.
    '''
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

print("\nHighlight the maximum value in last two columns:")
df.style.apply(highlight_max,subset=pd.IndexSlice[:, ['D', 'E']])
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Highlight the maximum value in last two columns:
# <style  type="text/css" >
#     #T_3891dbc4_a6f8_11ea_a700_0242ac1c0002row2_col4 {
#             background-color:  green;
#         }    #T_3891dbc4_a6f8_11ea_a700_0242ac1c0002row8_col3 {
#             background-color:  green;
# ...

# %% [markdown]
# **6, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để đặt nền nền khung dữ liệu Màu đen và màu phông chữ màu vàng.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to set dataframe background Color black and font color yellow.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-6-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
print("\nBackground:black - fontcolor:yelow")
df.style.set_properties(**{'background-color': 'black',
                           'color': 'yellow'})
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Background:black - fontcolor:yelow
# <style  type="text/css" >
#     #T_8542ad36_a6f8_11ea_a700_0242ac1c0002row0_col0 {
#             background-color:  black;
#             color:  yellow;
#         }    #T_8542ad36_a6f8_11ea_a700_0242ac1c0002row0_col1 {
#             background-color:  black;
#             color:  yellow;
#         }    #T_8542ad36_a6f8_11ea_a700_0242ac1c0002row0_col2 {
# ...

# %% [markdown]
# **7, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để làm nổi bật các cột cụ thể của dataframe.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight dataframe's specific columns.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-7-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
def highlight_cols(s):
    color = 'grey'
    return 'background-color: %s' % color
print("\nHighlight specific columns:")
df.style.applymap(highlight_cols, subset=pd.IndexSlice[:, ['B', 'C']])
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Highlight specific columns:
# <style  type="text/css" >
#     #T_9f976654_a6f8_11ea_a700_0242ac1c0002row0_col1 {
#             background-color:  grey;
#         }    #T_9f976654_a6f8_11ea_a700_0242ac1c0002row0_col2 {
#             background-color:  grey;
#         }    #T_9f976654_a6f8_11ea_a700_0242ac1c0002row1_col1 {
#             background-color:  grey;
#         }    #T_9f976654_a6f8_11ea_a700_0242ac1c0002row1_col2 {
# ...

# %% [markdown]
# **8, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để làm nổi bật các cột cụ thể của dataframe với các màu khác nhau.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight dataframe’s specific columns with different colors.**
#
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-8-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
print("\nDifferent background color:")
coldict = {'B':'red', 'D':'yellow'}

def highlight_cols(x):
    #copy df to new - original data are not changed
    df = x.copy()
    #select all values to default value - red color
    df.loc[:,:] = 'background-color: red'
    #overwrite values grey color
    df[['B','C', 'E']] = 'background-color: grey'
    #return color df
    return df    

df.style.apply(highlight_cols, axis=None)
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Different background color:
# <style  type="text/css" >
#     #T_c4c7f0ba_a6f8_11ea_a700_0242ac1c0002row0_col0 {
#             background-color:  red;
#         }    #T_c4c7f0ba_a6f8_11ea_a700_0242ac1c0002row0_col1 {
#             background-color:  grey;
#         }    #T_c4c7f0ba_a6f8_11ea_a700_0242ac1c0002row0_col2 {
#             background-color:  grey;
#         }    #T_c4c7f0ba_a6f8_11ea_a700_0242ac1c0002row0_col3 {
# ...

# %% [markdown]
# **9, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để hiển thị khung dữ liệu theo kiểu bảng.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to display the dataframe in table style.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-9-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
print("\nDataframe - table style:")
# Set CSS properties for th elements in dataframe
th_props = [
  ('font-size', '12px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', '#6d6d6d'),
  ('background-color', '#f7ffff')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '12px')
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]
(df.style
        .set_table_styles(styles))
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Dataframe - table style:
# <style  type="text/css" >
#     #T_e0d28fae_a6f8_11ea_a700_0242ac1c0002 th {
#           font-size: 12px;
#           text-align: center;
#           font-weight: bold;
#           color: #6d6d6d;
#           background-color: #f7ffff;
#     }    #T_e0d28fae_a6f8_11ea_a700_0242ac1c0002 td {
#           font-size: 12px;
# ...

# %% [markdown]
# **10, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để tô sáng toàn bộ hàng màu Vàng trong đó giá trị cột cụ thể lớn hơn 0,5.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight the entire row in Yellow where a specific column value is greater than 0.5**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-10-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
print("Original array:")
print(df)
print("\nDataframe - Highlight an entire row on specific condition:")

def highlight_greaterthan(x):
    if x.C > .5:
        return ['background-color: yellow']*5
    else:
        return ['background-color: white']*5 
df.style.apply(highlight_greaterthan, axis=1)
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212 -0.770033 -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720
#
# Dataframe - Highlight an entire row on specific condition:
# <style  type="text/css" >
#     #T_1953eed6_a6f9_11ea_a700_0242ac1c0002row0_col0 {
#             background-color:  white;
#         }    #T_1953eed6_a6f9_11ea_a700_0242ac1c0002row0_col1 {
#             background-color:  white;
#         }    #T_1953eed6_a6f9_11ea_a700_0242ac1c0002row0_col2 {
#             background-color:  white;
# ...

# %% [markdown]
# **11, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để hiển thị khung dữ liệu theo kiểu Heatmap.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to display the dataframe in Heatmap style.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-11-output.png)

# %%
import seaborn as sns
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
print("Original array:")
print(df)
print("\nDataframe - Heatmap style:")

cm = sns.light_palette("red", as_cmap=True)
 
df.style.background_gradient(cmap='viridis')
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212 -0.770033 -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720
#
# Dataframe - Heatmap style:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <style  type="text/css" >
#     #T_4246dd9e_a6f9_11ea_a700_0242ac1c0002row0_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# **12, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để tạo ánh xạ màu gradient trên một cột được chỉ định.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to make a gradient color mapping on a specified column.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-12-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
print("Original array:")
print(df)
print("\nDataframe - Gradient color:")
df.style.background_gradient(subset=['C'])
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212 -0.770033 -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720
#
# Dataframe - Gradient color:
# <style  type="text/css" >
#     #T_638ffb2a_a6f9_11ea_a700_0242ac1c0002row0_col2 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_638ffb2a_a6f9_11ea_a700_0242ac1c0002row1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_638ffb2a_a6f9_11ea_a700_0242ac1c0002row2_col2 {
# ...

# %% [markdown]
# **13, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để tạo màu gradient trên tất cả các giá trị của khung dữ liệu đã nói.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to make a gradient color on all the values of the said dataframe.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-13-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
print("Original array:")
print(df)
print("\nDataframe - Gradient color:")
df.style.background_gradient()
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212 -0.770033 -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720
#
# Dataframe - Gradient color:
# <style  type="text/css" >
#     #T_7e32e924_a6f9_11ea_a700_0242ac1c0002row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7e32e924_a6f9_11ea_a700_0242ac1c0002row0_col1 {
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }    #T_7e32e924_a6f9_11ea_a700_0242ac1c0002row0_col2 {
# ...

# %% [markdown]
# **14, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để hiển thị khung dữ liệu theo kiểu bảng và viền xung quanh bảng chứ không phải xung quanh các hàng.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to display the dataframe in table style and border around the table and not around the rows.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-14-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
print("\nDataframe - table style and border around the table and not around the rows:")
df.style.set_table_styles([{'selector':'','props':[('border','4px solid #7a7')]}])
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Dataframe - table style and border around the table and not around the rows:
# <style  type="text/css" >
#     #T_9680f462_a6f9_11ea_a700_0242ac1c0002  {
#           border: 4px solid #7a7;
# ...

# %% [markdown]
# **15, Tạo một khung dữ liệu gồm mười hàng, bốn cột với các giá trị ngẫu nhiên. Viết chương trình Pandas để hiển thị biểu đồ thanh trong khung dữ liệu trên các cột được chỉ định.**
#
# **Create a dataframe of ten rows, four columns with random values. Write a Pandas program to display bar charts in dataframe on specified columns.**
#
# ![alt text](https://www.w3resource.com/w3r_images/pandas-style-exercise-15-output.png)

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
print("\nBar charts in dataframe:")
df.style.bar(subset=['B', 'C'], color='#d65f5f')
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Bar charts in dataframe:
# <style  type="text/css" >
#     #T_a83202d2_a6f9_11ea_a700_0242ac1c0002row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 89.2%, transparent 89.2%);
#         }    #T_a83202d2_a6f9_11ea_a700_0242ac1c0002row1_col1 {
#             width:  10em;
#              height:  80%;
# ...
